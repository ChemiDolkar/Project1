# %% [markdown]
# # 2014-15 To 2016-17 School- Level NYC Regents Report

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# ...

# %%
df.groupby(['Regents Exam'])['Year'].count().sort_values(ascending=True)
# Out:
# Regents Exam
# Physical Settings/Physics           5799
# Common Core Algebra2                7915
# Geometry                            8509
# Algebra2/Trigonometry              10788
# Integrated Algebra                 11022
# English                            11091
# Physical Settings/Chemistry        11670
# Common Core Geometry               15267
# Physical Settings/Earth Science    15971
# Global History and Geography       19192
# Common Core English                19878
# U.S. History and Government        20426
# Living Environment                 25539
# Common Core Algebra                29254
# Name: Year, dtype: int64

# %%
#Bar chart showing total number of tests conducted by all the schools on each subjects. 
df.groupby(['Regents Exam'])['Year'].count().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='Regents Exam'>

# %%
#A random choice of a school
school_df=df.loc[df['School Name']=='47 The American Sign Language and English Secondar']
school_df
# Out:
#        School DBN                                        School Name  \
# 281        02M047  47 The American Sign Language and English Seco...
# 282        02M047  47 The American Sign Language and English Seco...
# 283        02M047  47 The American Sign Language and English Seco...
# 284        02M047  47 The American Sign Language and English Seco...
# 285        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141024     02M047  47 The American Sign Language and English Seco...
# 141025     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                 Regents Exam  Year  Total Tested  \
# ...

# %%
df[df['Regents Exam']=='Common Core Algebra']
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 8          01M184            P.S. 184m Shuang Wen          K-8
# 9          01M184            P.S. 184m Shuang Wen          K-8
# ...           ...                             ...          ...
# 212319     84X717            Icahn Charter School          K-8
# 212320     84X717            Icahn Charter School          K-8
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 3       Common Core Algebra  2016             3          s
# ...

# %%
df.groupby(['School Name'])['Percent Scoring CR'].describe()
# Out:
#                                                    count unique top freq
# School Name
# 47 The American Sign Language and English Secondar   356     52  na  249
# A. Philip Randolph Campus High School                459    133  na  272
# ACORN Community High School                          364     68  na  263
# Abraham Lincoln High School                          480    173  na  271
# Abraham Lincoln Yabc                                 248     33  na  184
# ...                                                  ...    ...  ..  ...
# Young Women's Leadership School                      378     90  na  254
# Young Women's Leadership School of Brooklyn          337     64  na  235
# Young Women's Leadership School of the Bronx         142     23  na  110
# Young Women's Leadership School, Astoria             338     81  na  224
# Young Women's Leadership School, Queens              391     93  na  265
#
# [1012 rows x 4 columns]

# %%
#An attempt to plot bar diagram with the list of schools and number of students who have met college readiness benchmark. 
df=pd.DataFrame(np.random.rand(50,2),columns=['School Name', 'Number Scoring CR'])
df.plot.bar(x='School Name',y='Number Scoring CR')
# Out:
# <AxesSubplot:xlabel='School Name'>
